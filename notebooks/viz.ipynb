# %%
import pandas as pd 
from pathlib import Path
from plotly import express as px
data_dir= Path("data")

gdp_file=Path(data_dir / "gdp_per_capita.csv")
oecd_file=Path(data_dir / "oecd_bli_2015.csv")

gdp_df= pd.read_csv(gdp_file,thousands=',', delimiter='\t',encoding="latin1",na_values="n/a")
oecd_df= pd.read_csv(oecd_file, thousands=',')

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression


def prepare_country_stats(oecd_df, gdp_df):
    oecd_countries= oecd_df[oecd_df["INEQUALITY"]=="TOT"]
    oecd_countries= oecd_countries.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita= gdp_df[["Country", "2015"]]
    gdp_per_capita= gdp_per_capita.rename(columns={"2015": "GDP per capita"})
    gdp_per_capita= gdp_per_capita.set_index("Country")
    full_country_stats= pd.merge(left=oecd_countries, right=gdp_per_capita, left_index=True, right_index=True)
    full_country_stats= full_country_stats.sort_values(by="GDP per capita")
    remove_indices= [0, 1, 6, 8, 33, 34, 35]
    keep_indices= list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita","Life satisfaction"]].iloc[keep_indices]

country_stats=prepare_country_stats(oecd_df, gdp_df)
X= np.c_[country_stats["GDP per capita"]]
y= np.c_[country_stats["Life satisfaction"]]

X_new = [[22587]]
model= LinearRegression()
model.fit(X, y)
print(model.predict(X_new))  # Predict life satisfaction for GDP per capita of 22,
# Out:
# [[5.96242338]]

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [4.8530528]
# [[4.91154459e-05]]

# %%
from sklearn.neighbors import KNeighborsRegressor
X_new = [[20732]]
knn_model= KNeighborsRegressor(n_neighbors=3)
knn_model.fit(X, y)
print(knn_model.predict(X_new))
# Out:
# [[5.2]]

# %%
import pandas as pd
model_comparison=pd.read_json("model_comparison_results.json")
# view model comparison results sort by Test R2 score
model_comparison.sort_values(by="Test R2", ascending=False)
# Out:
#                   Pipeline         Model  Train R2   Test R2  Test R2 Std  \
# 0         pipe2_no_grouper  RandomForest  0.846498  0.762681     0.077233
# 1       pipe5_ratio_scaled  RandomForest  0.847582  0.760889     0.072014
# 2          pipe2_optimized  RandomForest  0.844350  0.756838     0.072766
# 3          pipe1_optimized  RandomForest  0.841507  0.752839     0.080601
# 4      pipe7_rare_moderate  RandomForest  0.841443  0.752481     0.084134
# 5         pipe4_target_enc  RandomForest  0.839194  0.752423     0.067725
# 6       pipe3_with_grouper  RandomForest  0.828412  0.751423     0.071241
# 7   pipe1_optimized_scaled  RandomForest  0.842851  0.751050     0.072324
# 8    catboost_pipe_nogroup      CatBoost  0.858797  0.750937     0.072286
# 9               pipe6_poly  RandomForest  0.856238  0.747454     0.077395
# 10      pipe3_with_grouper       XGBoost  0.860865  0.746449     0.068362
# 11        pipe2_no_grouper        HistGB  0.830504  0.744408     0.066743
# 12      pipe5_ratio_scaled        HistGB  0.832458  0.744159     0.071721
# 13        pipe4_target_enc        HistGB  0.831668  0.743988     0.064587
# 14           catboost_pipe      CatBoost  0.842461  0.739924     0.072716
# 15         pipe2_optimized        HistGB  0.842510  0.739700     0.071856
# 16              pipe6_poly        HistGB  0.858887  0.738427     0.072385
# 17     pipe7_rare_moderate        HistGB  0.816354  0.737318     0.070783
# 18     pipe7_rare_moderate       XGBoost  0.872675  0.736992     0.062561
# 19        pipe1_no_scaling       XGBoost  0.861835  0.730877     0.069195
# 20         pipe1_optimized        HistGB  0.831157  0.730642     0.078665
# 21  pipe1_optimized_scaled        HistGB  0.829431  0.728897     0.070962
# 22      pipe3_with_grouper        HistGB  0.822125  0.728718     0.068505
# 23              pipe6_poly       XGBoost  0.907616  0.728321     0.070969
# 24        pipe4_target_enc       XGBoost  0.858633  0.719579     0.060478
# 25      pipe5_ratio_scaled       XGBoost  0.879610  0.716565     0.083846
# 26         pipe2_optimized       XGBoost  0.864772  0.712618     0.087879
# 27        pipe1_no_scaling        HistGB  0.780609  0.704237     0.068708
# 28         pipe1_optimized       XGBoost  0.860993  0.701083     0.049468
# 29        pipe1_no_scaling  RandomForest  0.836642  0.698213     0.079270
# 30  pipe1_optimized_scaled       XGBoost  0.865746  0.695714     0.058710
# 31        pipe2_no_grouper       XGBoost  0.842401  0.686018     0.075239
#
#     Test RMSE  Test MAE                                        Best Params
# 0    0.352976  0.177295  {'model__max_depth': 15, 'model__min_samples_l...
# 1    0.354819  0.175598  {'model__max_depth': 20, 'model__min_samples_l...
# 2    0.357777  0.176294  {'model__max_depth': 15, 'model__min_samples_l...
# 3    0.360155  0.181218  {'model__max_depth': 15, 'model__min_samples_l...
# 4    0.360160  0.181462  {'model__max_depth': 15, 'model__min_samples_l...
# 5    0.361477  0.178866  {'model__max_depth': 15, 'model__min_samples_l...
# 6    0.361938  0.181519  {'model__max_depth': 20, 'model__min_samples_l...
# 7    0.362202  0.182591  {'model__max_depth': 15, 'model__min_samples_l...
# 8    0.362168  0.197576  {'model__depth': 8, 'model__iterations': 500, ...
# 9    0.364307  0.184053  {'model__max_depth': 15, 'model__min_samples_l...
# 10   0.365735  0.197482  {'model__learning_rate': 0.05, 'model__max_dep...
# 11   0.367454  0.194518  {'model__learning_rate': 0.03, 'model__max_dep...
# 12   0.367270  0.198279  {'model__learning_rate': 0.03, 'model__max_dep...
# 13   0.367850  0.196088  {'model__learning_rate': 0.03, 'model__max_dep...
# 14   0.370111  0.205580  {'model__depth': 6, 'model__iterations': 800, ...
# 15   0.370448  0.198547  {'model__learning_rate': 0.05, 'model__max_dep...
# 16   0.371429  0.201165  {'model__learning_rate': 0.03, 'model__max_dep...
# 17   0.372331  0.203024  {'model__learning_rate': 0.03, 'model__max_dep...
# 18   0.373002  0.196853  {'model__learning_rate': 0.05, 'model__max_dep...
# 19   0.376479  0.209684  {'model__learning_rate': 0.05, 'model__max_dep...
# 20   0.376614  0.203908  {'model__learning_rate': 0.05, 'model__max_dep...
# 21   0.378349  0.203733  {'model__learning_rate': 0.05, 'model__max_dep...
# 22   0.378595  0.201044  {'model__learning_rate': 0.03, 'model__max_dep...
# 23   0.378794  0.189989  {'model__learning_rate': 0.05, 'model__max_dep...
# 24   0.384835  0.193654  {'model__learning_rate': 0.05, 'model__max_dep...
# 25   0.385600  0.194856  {'model__learning_rate': 0.05, 'model__max_dep...
# 26   0.387840  0.186229  {'model__learning_rate': 0.05, 'model__max_dep...
# 27   0.395384  0.224694  {'model__learning_rate': 0.05, 'model__max_dep...
# 28   0.398203  0.201680  {'model__learning_rate': 0.05, 'model__max_dep...
# 29   0.399046  0.217147  {'model__max_depth': 20, 'model__min_samples_l...
# 30   0.401443  0.197589  {'model__learning_rate': 0.05, 'model__max_dep...
# 31   0.405715  0.189593  {'model__learning_rate': 0.05, 'model__max_dep...

# %%
# plot model comparison by model and pipeline
fig= px.bar(model_comparison, x=model_comparison.index, y="Test R2", color="Pipeline", barmode="group",
            title="Model Comparison by Pipeline",
            labels={"x": "Model", "Test R2": "Test R2 Score"})
fig.show()
